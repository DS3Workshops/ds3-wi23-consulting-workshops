# %% [markdown]
# **We are using examples and dataset from this kaggle case study: https://www.kaggle.com/code/tasneemabdulrahim/data-science-project-lifecycle-a-case-study/notebook**

# %% [markdown]
# Today we are given a dataset: Yahoo Stock Price (first 10 rows):
# ![Screen%20Shot%202023-02-03%20at%2012.46.22%20PM.png](attachment:Screen%20Shot%202023-02-03%20at%2012.46.22%20PM.png)

# %% [markdown]
# # Step 1: Ideation
# First, we need to come up with our question first: what is the problem that we are trying to solve?
#
# In this example, the author asked: what will be the value of Yahoo's assets in the near future?
#
# **Come up with your own question! Double click the cell below to edit.**

# %% [markdown]
# ...

# %% [markdown]
# # Step 2: Data Acquisition
# We have our data already!
# What if today the data isn't provided? What are some ways we can collect the data we need?

# %% [markdown]
# ...

# %% [markdown]
# # Step 3: Data Preparation / Exploration
# What are some tasks we can perform during this step?
#
# Some examples we talked about previously today: Data cleaning, combining the current data with other datasets, visualizing the data, loading the data into the target location (i.e. a cloud platform), etc.

# %% [markdown]
# ...

# %% [markdown]
# # Step 4: Research & Development
# **1. Conducting Exploratory Data Analysis (EDA)**
# - Do we have any assumptions or hypotheses about the data?
# - What can you do / what tools can use to quickly test your assumptions and understand the relationships between various features?
#
# Example of what the author of this kaggle case study did:
# ![Screen%20Shot%202023-02-03%20at%2012.53.38%20PM.png](attachment:Screen%20Shot%202023-02-03%20at%2012.53.38%20PM.png)
#
# **What would you do?**

# %% [markdown]
# ...

# %% [markdown]
# **2. Model Building**
# - What approach can we take?
# - What model is best fit for the data?
#
# In this example, the author uses a regression model.
#
# ![Screen%20Shot%202023-02-03%20at%201.42.27%20PM.png](attachment:Screen%20Shot%202023-02-03%20at%201.42.27%20PM.png)
#
# Notice how the dataset is split into train & test datasets. The test dataset will later be used for comparison.
#
# **What would you do?**

# %% [markdown]
# ...

# %% [markdown]
# # Step 5: Validation and Ethical Considerations
# **1. Validation**
# In this case study, the author uses Mean Absolute Error (MAE) for model evaluation.
#
# *MAE is a measure of errors between paired observations expressing the same phenomenon, i.e. actual values vs. predcited values.*
#
# ![Screen%20Shot%202023-02-03%20at%201.44.31%20PM.png](attachment:Screen%20Shot%202023-02-03%20at%201.44.31%20PM.png)
#
# **What are some ways we can improve our model?**

# %% [markdown]
# ...

# %% [markdown]
# **2. Ethical Considerations**
# - Are we being fair, accountable and transparent?
# - Do they run the risk of harming anybody? If so, how?
# - How can we prevent our findings from being misinterpreted?
# - Are our findings reproducible?

# %% [markdown]
# ...

# %% [markdown]
# # Step 6: Present, Deploy, and Monitor
# Now, we are at the final stage of the lifecycle of data science.
#
# If we are deploying a product, the model is exposed to real time data flowing into the system and outputs are being generated so we need to ensure that no edge cases arise and that the model continues to perform.
